# %% [markdown]
# # Level 3: Document-Specific Splitting
#
# **Opis:** Strategia dostosowana do formatu (Markdown, kod, PDF).
#
# **Cel:** Wykorzystanie naturalnych separatorów (nagłówki, definicje klas).

# %%
# TODO: Implement Level 3 - Document-Specific Splitting
# - MarkdownHeaderTextSplitter / PythonCodeTextSplitter
# - Or use unstructured library for PDF/HTML
# - Display chunks with metadata
