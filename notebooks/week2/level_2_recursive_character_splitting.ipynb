# %% [markdown]
# # Level 2: Recursive Character Splitting
#
# **Opis:** Dzielenie z uwzględnieniem struktury (akapity, nowe linie, znaki interpunkcyjne).
#
# **Zalecenie:** ⭐ Zalecany punkt startowy dla większości projektów.

# %%
# TODO: Implement Level 2 - Recursive Character Splitting
# - Use LangChain RecursiveCharacterTextSplitter
# - Configure separators (e.g., \n\n, \n, " ", "")
# - Display chunks
